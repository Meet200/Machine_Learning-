# %% [markdown]
# <a href="https://colab.research.google.com/github/Meet200/Machine_Learning-/blob/main/Multi_variable_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/"My Drive/Colab Notebooks/Linear regression"
# Out:
# /content/drive/My Drive/Colab Notebooks/Linear regression

# %%
dataset = pd.read_csv("Real estate.csv")
print(dataset.head)
# Out:
# <bound method NDFrame.head of       No  X1 transaction date  ...  X6 longitude  Y house price of unit area
# 0      1             2012.917  ...     121.54024                        37.9
# 1      2             2012.917  ...     121.53951                        42.2
# 2      3             2013.583  ...     121.54391                        47.3
# 3      4             2013.500  ...     121.54391                        54.8
# 4      5             2012.833  ...     121.54245                        43.1
# ..   ...                  ...  ...           ...                         ...
# 409  410             2013.000  ...     121.50381                        15.4
# 410  411             2012.667  ...     121.54310                        50.0
# 411  412             2013.250  ...     121.53986                        40.6
# 412  413             2013.000  ...     121.54067                        52.5
# 413  414             2013.500  ...     121.54310                        63.9
#
# ...

# %%
dataset.shape
# Out:
# (414, 8)

# %%
x1 = dataset.iloc[0:dataset.shape[0],1:2]
x2 = dataset.iloc[0:dataset.shape[0],2:3]
x3 = dataset.iloc[0:dataset.shape[0],3:4]
x4 = dataset.iloc[0:dataset.shape[0],4:5]
x5 = dataset.iloc[0:dataset.shape[0],5:6]
x6 = dataset.iloc[0:dataset.shape[0],6:7]
x7 = dataset.iloc[0:dataset.shape[0],7:8]
x7
# Out:
#      Y house price of unit area
# 0                          37.9
# 1                          42.2
# 2                          47.3
# 3                          54.8
# 4                          43.1
# ..                          ...
# 409                        15.4
# 410                        50.0
# 411                        40.6
# 412                        52.5
# 413                        63.9
#
# [414 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
fig,axes=plt.subplots(figsize=(20,8),nrows=1,ncols=6)
axes[0].scatter(x1,x2,color='r')
axes[0].set_xlabel("x1 house transaction")
axes[0].set_ylabel("x2 house transaction")
axes[0].set_title("x1 v/s x2")

axes[1].scatter(x1,x3,color='r')
axes[1].set_xlabel("x1 house transaction")
axes[1].set_ylabel("x3 house transaction")
axes[1].set_title("x1 v/s x3")

axes[2].scatter(x1,x4,color='r')
axes[2].set_xlabel("x1 house transaction")
axes[2].set_ylabel("x4 house transaction")
axes[2].set_title("x1 v/s x4")

axes[3].scatter(x1,x5,color='r')
axes[3].set_xlabel("x1 house transaction")
axes[3].set_ylabel("x5 house transaction")
axes[3].set_title("x1 v/s x5")

axes[4].scatter(x1,x6,color='r')
axes[4].set_xlabel("x1 house transaction")
axes[4].set_ylabel("x6 house transaction")
axes[4].set_title("x1 v/s x6")

axes[5].scatter(x1,x7,color='r')
axes[5].set_xlabel("x1 house transaction")
axes[5].set_ylabel("x7 house transaction")
axes[5].set_title("x1 v/s x7")

plt.tight_layout()

# %%
def feature_normalization(X):
    mean = np.mean(X,axis=0)
    std = np.std(X,axis=0)
    X_norm = (X-mean)/std

    return X_norm,mean,std

# %%
data = dataset.values    
n = len(data[:,-1])
X=dataset
X_norm,mean,std = feature_normalization(X)

# %%
Y=data[:,-1].reshape(n,1)
theta_array = np.zeros((7,1))

# %%
def hypothesis(theta_array,x1,x2,x3,x4,x5):     
    return theta_array[0]+(theta_array[1]*x1)+(theta_array[2]*x2)+(theta_array[3]*x3)+(theta_array[4]*x4)+(theta_array[5]*x5) (theta_array[6]*x6) (theta_array[7]*x7)

# %%
def cost_function(theta_array,x1,x2,x3,x4,x5,x6,x7,y,m):   
    total_error = 0     
    for i in range(m):
        total_error+=(theta_array[0]+theta_array[1]*x1[i]+theta_array[2]*x2[i]+theta_array[3]*x3[i]+theta_array[4]*x4[i] +theta_array[5]*x5[i] +theta_array[6]*x6[i] +theta_array[7]*x7[i] - y[i])**2

    return total_error/(2*m)

# %%
def gradient_descent(theta_array,x1,x2,x3,x4,x5,x6,x7,y,alpha,m):
    summation_theta0 = 0
    summation_theta1 = 0
    summation_theta2 = 0
    summation_theta3 = 0
    summation_theta4 = 0
    summation_theta5 = 0
    summation_theta6 = 0
    summation_theta7 = 0

    for i in range(m):
        summation_theta0+=((theta_array[0]+theta_array[1]*x1[i]+theta_array[2]*x2[i]) - y[i])
        summation_theta1+=(((theta_array[0]+theta_array[1]*x1[i]+theta_array[2]*x2[i]) - y[i])*x1[i])
        summation_theta2+=(((theta_array[0]+theta_array[1]*x1[i]+theta_array[2]*x2[i]) - y[i])*x2[i])
        summation_theta3+=(((theta_array[0]+theta_array[1]*x1[i]+theta_array[2]*x2[i]) - y[i])*x3[i])
        summation_theta4+=(((theta_array[0]+theta_array[1]*x1[i]+theta_array[2]*x2[i]) - y[i])*x4[i])
        summation_theta5+=(((theta_array[0]+theta_array[1]*x1[i]+theta_array[2]*x2[i]) - y[i])*x5[i])
        summation_theta6+=(((theta_array[0]+theta_array[1]*x1[i]+theta_array[2]*x2[i]) - y[i])*x6[i])
        summation_theta7+=(((theta_array[0]+theta_array[1]*x1[i]+theta_array[2]*x2[i]) - y[i])*x7[i])

    new_theta0 = theta_array[0]-alpha*(summation_theta0/m)
    new_theta1 = theta_array[1]-alpha*(summation_theta1/m)
    new_theta3 = theta_array[3]-alpha*(summation_theta3/m)
    new_theta2 = theta_array[2]-alpha*(summation_theta2/m)
    new_theta4 = theta_array[4]-alpha*(summation_theta4/m)
    new_theta5 = theta_array[5]-alpha*(summation_theta5/m)
    new_theta6 = theta_array[5]-alpha*(summation_theta6/m)
    new_theta7 = theta_array[5]-alpha*(summation_theta7/m)

    updated_theta_array = [new_theta0,new_theta1,new_theta2,new_theta3,new_theta4,new_theta5 ,new_theta6 ,new_theta7]
    print(updated_theta_array)
    return updated_theta_array

# %%
def training(x1,x2,x3,x4,x5,x6,x7,y,alpha,iters):
    theta_0 = 0
    theta_1 = 0
    theta_2 = 0
    theta_3 = 0
    theta_4 = 0
    theta_5 = 0
    theta_6 = 0
    theta_7 = 0
    theta_array = [theta_0,theta_1,theta_2,theta_3,theta_4,theta_5,theta_6,theta_7]

    m=x1.size               
    cost_function_values = []
    for i in range(iters):
        theta_array = gradient_descent(theta_array,x1,x2,x3,x4,x5,x6,x7,y,alpha,m)   
        cost_function_values.append(cost_function(theta_array,x1,x2,x3,x4,x5,x6,x7,y,m))  
        if(i%5==0):
            y_new=x5*theta_array[5]+x4*theta_array[4]+x3*theta_array[3]+x2*theta_array[2]+x1*theta_array[1]+theta_array[0] +x6*theta_array[6] + +x7*theta_array[7]
            plt.plot(x1,y_new,'r')
            plt.scatter(x1,y)
            plt.show()

    x=np.arange(0,len(cost_function_values),step=1)
    plt.plot(x,cost_function_values,"-b")
    plt.xlabel("number of iteration")
    plt.ylabel("Cost/loss values")
    plt.title("cost Function curve")
    plt.show()

    return theta_array

# %%
theta_array = training(data[:,1:2],data[:,2:3],data[:,3:4],data[:,4:5],data[:,5:6],data[:,6:7],data[:,7:8],Y,0.00001,5)
# Out:
# [array([0.0003798]), array([0.76460122]), array([0.00640165]), array([0.29626258]), array([0.00178329]), array([0.00948421]), array([0.0461597]), array([0.01627184])]
# [array([-0.0146341]), array([-29.46060797]), array([-0.25986725]), array([-16.09267394]), array([-0.05945853]), array([-0.36539733]), array([-1.81520411]), array([-0.5589001])]
# [array([0.57887781]), array([1165.36729685]), array([10.2527756]), array([627.09830769]), array([2.3707346]), array([14.45402022]), array([71.76610017]), array([22.17816038])]
# [array([-22.88314395]), array([-46067.17859607]), array([-405.3339574]), array([-24803.45626578]), array([-93.68757785]), array([-571.36990799]), array([-2836.96433828]), array([-876.63681692])]
# [array([904.59019158]), array([1821074.84925353]), array([16023.14389279]), array([980482.9498561]), array([3703.58707609]), array([22586.73978686]), array([112147.58176351]), array([34654.27071955])]

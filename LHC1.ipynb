# %% [markdown]
# <a href="https://colab.research.google.com/github/Meet200/Machine_Learning-/blob/main/LHC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/"My Drive/Colab Notebooks/Linear regression"
# Out:
# /content/drive/My Drive/Colab Notebooks/Linear regression

# %% [markdown]
# Analyse the growth rate of covid-19 in INDIA with referenceto number of cases, deaths and recovered. You may use the 7-days moving average for better graph visualization

# %%
# confirmed cases
dataset = pd.read_csv("time_series_covid19_confirmed_global.csv")
india= dataset[dataset['Country/Region']=='India']
indi= india.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
indi.index = ["Confirmed"]
d = indi.transpose()

# Recovered cases
dataset2 = pd.read_csv("time_series_covid19_recovered_global.csv")
india2= dataset2[dataset2['Country/Region']=='India']
indi2= india2.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
indi2.index = ["Recover"]
d2 = indi2.transpose()
d['Recover'] = d2

# Death cases
dataset3 = pd.read_csv("time_series_covid19_deaths_global.csv")
india3= dataset3[dataset3['Country/Region']=='India']
indi3= india3.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
indi3.index = ["Death"]
d3= indi3.transpose()
d['Death'] = d3
d
# Out:
#             Confirmed     Recover     Death
# 1/22/20             0         0.0       0.0
# 1/23/20             0         0.0       0.0
# 1/24/20             0         0.0       0.0
# 1/25/20             0         0.0       0.0
# 1/26/20             0         0.0       0.0
# ...               ...         ...       ...
# 4/29/21      18762976  15384418.0  208330.0
# 4/30/21      19164969  15684406.0  211853.0
# 05-01-2021   19557457         NaN       NaN
# 05-02-2021   19925517         NaN       NaN
# 05-03-2021   19925604         NaN       NaN
#
# [468 rows x 3 columns]

# %%
plt.plot(d.index, d['Confirmed'], label = "Confirmed", linestyle="-")
plt.plot(d.index, d['Death'], label = "Deaths", linestyle="--")
plt.plot(d.index, d['Recover'], label = "Recovered", linestyle="-.")
plt.xlabel("Days")
plt.ylabel("Number of Cases")
plt.title("Indian Covid Cases")
plt.legend()
plt.show()

# %% [markdown]
# Perform part-1 for US and Italy.

# %%
# confirmed cases
dataset = pd.read_csv("time_series_covid19_confirmed_global.csv")
india= dataset[dataset['Country/Region']=='US']
indi= india.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
indi.index = ["Confirmed"]
d = indi.transpose()

# Recovered cases
dataset2 = pd.read_csv("time_series_covid19_recovered_global.csv")
india2= dataset2[dataset2['Country/Region']=='US']
indi2= india2.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
indi2.index = ["Recover"]
d2 = indi2.transpose()
d['Recover'] = d2

# Death cases
dataset3 = pd.read_csv("time_series_covid19_deaths_global.csv")
india3= dataset3[dataset3['Country/Region']=='US']
indi3= india3.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
indi3.index = ["Death"]
d3= indi3.transpose()
d['Death'] = d3
d
# Out:
#             Confirmed  Recover     Death
# 1/22/20             1      0.0       0.0
# 1/23/20             1      0.0       0.0
# 1/24/20             2      0.0       0.0
# 1/25/20             2      0.0       0.0
# 1/26/20             5      0.0       0.0
# ...               ...      ...       ...
# 4/29/21      32289049      0.0  575290.0
# 4/30/21      32346971      0.0  576328.0
# 05-01-2021   32392274      NaN       NaN
# 05-02-2021   32421641      NaN       NaN
# 05-03-2021   32470920      NaN       NaN
#
# [468 rows x 3 columns]

# %%
plt.plot(d.index, d['Confirmed'], label = "Confirmed", linestyle="-")
plt.plot(d.index, d['Death'], label = "Deaths", linestyle="--")
plt.plot(d.index, d['Recover'], label = "Recovered", linestyle="-.")
plt.xlabel("Days")
plt.ylabel("Number of Cases")
plt.title("US Covid Cases")
plt.legend()
plt.show()

# %%
# confirmed cases
dataset = pd.read_csv("time_series_covid19_confirmed_global.csv")
india= dataset[dataset['Country/Region']=='Italy']
indi= india.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
indi.index = ["Confirmed"]
d = indi.transpose()

# Recovered cases
dataset2 = pd.read_csv("time_series_covid19_recovered_global.csv")
india2= dataset2[dataset2['Country/Region']=='Italy']
indi2= india2.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
indi2.index = ["Recover"]
d2 = indi2.transpose()
d['Recover'] = d2

# Death cases
dataset3 = pd.read_csv("time_series_covid19_deaths_global.csv")
india3= dataset3[dataset3['Country/Region']=='Italy']
indi3= india3.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
indi3.index = ["Death"]
d3= indi3.transpose()
d['Death'] = d3
d
# Out:
#             Confirmed    Recover     Death
# 1/22/20             0        0.0       0.0
# 1/23/20             0        0.0       0.0
# 1/24/20             0        0.0       0.0
# 1/25/20             0        0.0       0.0
# 1/26/20             0        0.0       0.0
# ...               ...        ...       ...
# 4/29/21       4009208  3449955.0  120544.0
# 4/30/21       4022653  3465576.0  120807.0
# 05-01-2021    4035617        NaN       NaN
# 05-02-2021    4044762        NaN       NaN
# 05-03-2021    4050708        NaN       NaN
#
# [468 rows x 3 columns]

# %%
plt.plot(d.index, d['Confirmed'], label = "Confirmed", linestyle="-")
plt.plot(d.index, d['Death'], label = "Deaths", linestyle="--")
plt.plot(d.index, d['Recover'], label = "Recovered", linestyle="-.")
plt.xlabel("Days")
plt.ylabel("Number of Cases")
plt.title("Italy Covid Cases")
plt.legend()
plt.show()

# %% [markdown]
# Train the ML model with the hypothesis of regression for India and predict the number of covid cases on 4thMay, 2021

# %%
a  = [i for i in range(1,469)]
d['x']= a
d
# Out:
#             Confirmed    Recover     Death    x
# 1/22/20             0        0.0       0.0    1
# 1/23/20             0        0.0       0.0    2
# 1/24/20             0        0.0       0.0    3
# 1/25/20             0        0.0       0.0    4
# 1/26/20             0        0.0       0.0    5
# ...               ...        ...       ...  ...
# 4/29/21       4009208  3449955.0  120544.0  464
# 4/30/21       4022653  3465576.0  120807.0  465
# 05-01-2021    4035617        NaN       NaN  466
# 05-02-2021    4044762        NaN       NaN  467
# 05-03-2021    4050708        NaN       NaN  468
#
# [468 rows x 4 columns]

# %%
X_features =  d.iloc[:,-1]
Y_features =d.iloc[:,0:1]
X_features = X_features.to_frame() 
Y_features
# Out:
#             Confirmed
# 1/22/20             0
# 1/23/20             0
# 1/24/20             0
# 1/25/20             0
# 1/26/20             0
# ...               ...
# 4/29/21       4009208
# 4/30/21       4022653
# 05-01-2021    4035617
# 05-02-2021    4044762
# 05-03-2021    4050708
#
# [468 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
prediction_model = LinearRegression().fit(X_features, Y_features)
x = np.array([469]).reshape(-1, 1)
x
# Out:
# array([[469]])

# %%
y_pred = prediction_model.predict(x)
print(y_pred)
# Out:
# [[3138051.41448416]]

# %%
from sklearn.linear_model import LinearRegression
lin = LinearRegression()
  
lin.fit(X_features, Y_features)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = prediction_model.predict(x)
print(int(y_pred))
# Out:
# 3138051

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 6)
X_poly = poly.fit_transform(X_features)
poly = poly.fit(X_poly, Y_features)
lin2 = LinearRegression()
lin2.fit(X_poly, Y_features)
x11 = np.array([469]).reshape(-1, 1)
x12 = np.array([468]).reshape(-1, 1)
ans11 = int(lin2.predict(poly.fit_transform(x11)))
ans12 = int(lin2.predict(poly.fit_transform(x12)))
fin_ind = 359942
print(ans11)  
print(ans12)
# Out:
# 4238443
# 4207393

# %% [markdown]
# Task-4 Analyse the cases of Confirmed, Death and Recovered figures from 01 March, 2021 in Gujarat

# %%
cd /content/drive/"My Drive/Colab Notebooks"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
import os
import glob
import pandas as pd

location = "LHC"

file_name = []
for file in os.listdir(location):
         file_name.append(file)
         
print(file_name)

#combine all files in the list
combined_csv = pd.concat([pd.read_csv("LHC/"+f) for f in file_name ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
# Out:
# ['03-26-2021.csv', '03-22-2021.csv', '03-20-2021.csv', '03-21-2021.csv', '03-25-2021.csv', '03-24-2021.csv', '03-22-2020.csv', '03-21-2020.csv', '03-23-2021.csv', '03-20-2020.csv', '03-19-2021.csv', '03-16-2021.csv', '03-17-2021.csv', '03-18-2021.csv', '03-14-2021.csv', '03-15-2021.csv', '03-08-2021.csv', '03-07-2021.csv', '03-06-2021.csv', '03-11-2021.csv', '03-19-2020.csv', '03-12-2021.csv', '03-18-2020.csv', '03-13-2021.csv', '03-05-2021.csv', '03-04-2021.csv', '03-01-2021.csv', '03-10-2021.csv', '03-03-2021.csv', '03-09-2021.csv', '03-02-2021.csv', '04-24-2021.csv', '04-23-2021.csv', '04-22-2021.csv', '04-21-2021.csv', '04-18-2021.csv', '04-17-2021.csv', '04-20-2021.csv', '04-19-2021.csv', '04-16-2021.csv', '04-15-2021.csv', '04-13-2021.csv', '04-12-2021.csv', '04-10-2021.csv', '04-09-2021.csv', '04-08-2021.csv', '04-07-2021.csv', '04-06-2021.csv', '04-14-2021.csv', '04-11-2021.csv', '04-05-2021.csv', '04-04-2021.csv', '03-30-2021.csv', '03-29-2021.csv', '03-28-2021.csv', '03-27-
# ...

# %%
data_india = combined_csv.loc[combined_csv['Country_Region']=='India']

data_india

data_india_gujrat = data_india.loc[data_india['Province_State']=='Gujarat']

data_india_gujrat.head(10)
data_india_gujrat = data_india_gujrat.sort_values(by=['Last_Update'])
data_india_gujrat

plt.plot(data_india_gujrat['Last_Update'], data_india_gujrat['Deaths'], label = "Deaths")
plt.plot(data_india_gujrat['Last_Update'], data_india_gujrat['Recovered'], label = "recovered")
plt.plot(data_india_gujrat['Last_Update'], data_india_gujrat['Confirmed'], label = "confirmed")
plt.xlabel("Days ")
plt.ylabel("cumulative Cases Death,Recovered,Confirmed")
plt.title("Gujarat Coivd status after  1st March 2021")
plt.legend()
plt.show()

# %%
# Using Linear regression
data_pred_guj = [i for i in range(1,65)]
df2 = data_india_gujrat
df2.insert(0,"Days",data_pred_guj,True)
df2

X_features = df2.iloc[:,0:1]
Y_features = df2.iloc[:,8:9]

print(Y_features)

from sklearn.linear_model import LinearRegression
prediction_model = LinearRegression().fit(X_features, Y_features)
x = np.array([65]).reshape(-1, 1)
x

y_pred_gujrat = prediction_model.predict(x)
print(int(y_pred_gujrat))
# Out:
#      Confirmed
# 259     270316
# 259     270770
# 259     271245
# 259     271725
# 259     272240
# ..         ...
# 259     553172
# 259     567777
# 259     581624
# 259     594602
# 259     594602
#
# [64 rows x 1 columns]
# 505455

# %%
from sklearn.linear_model import LinearRegression
prediction_model = LinearRegression().fit(X_features, Y_features)
x = np.array([65]).reshape(-1, 1)
x

y_pred_gujrat = prediction_model.predict(x)
print(int(y_pred_gujrat))
# Out:
# 505455

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2)
X_poly = poly.fit_transform(X_features)
poly = poly.fit(X_poly, Y_features)
lin2 = LinearRegression()
lin2.fit(X_poly, Y_features)
x = np.array([65]).reshape(-1, 1)
x2 = np.array([64]).reshape(-1, 1)
ans2 =int(lin2.predict(poly.fit_transform(x))) 
ans3 =int(lin2.predict(poly.fit_transform(x2))) 
print(ans2)
print(ans3)
# Out:
# 601388
# 588149

# %%
print("Total Case in gujrat on 4th May : ",(ans2-ans3))
fin_guj = ans2-ans3
# Out:
# Total Case in gujrat on 4th May :  13239

# %%
perct = float((fin_guj/(fin_ind))*100)
print(perct)
plt.pie([perct,100-perct],labels=['Gujarat','India - Gujrat'],colors=["orange","red"],
        explode=(0.1,0),shadow=True,autopct='%1.1f%%')
plt.title(" 4th May case comparison")
plt.legend()
plt.show()
print("number of cases in gujarat",13239)
print("number of cases in india",359940)
# Out:
# 3.6780925815825887
# number of cases in gujarat 13239
# number of cases in india 359940

# %% [markdown]
# Select state Bengal and analyse the confirmed cases from 01 march to 01 April and from 01 April to 01 May,2021.

# %%
data_india = combined_csv.loc[combined_csv['Country_Region']=='India']

data_india

data_india_gujrat = data_india.loc[data_india['Province_State']=='West Bengal']

data_india_gujrat.head(10)
data_india_gujrat = data_india_gujrat.sort_values(by=['Last_Update'])
data_india_gujrat

plt.plot(data_india_gujrat['Last_Update'], data_india_gujrat['Deaths'], label = "Deaths")
plt.plot(data_india_gujrat['Last_Update'], data_india_gujrat['Recovered'], label = "recovered")
plt.plot(data_india_gujrat['Last_Update'], data_india_gujrat['Confirmed'], label = "confirmed")
plt.xlabel("Days ")
plt.ylabel("cumulative Cases Death,Recovered,Confirmed")
plt.title("Bengal Coivd status after  1st march 2021")
plt.legend()
plt.show()

# %%
data_india_Bengal = data_india.loc[data_india['Province_State']=='West Bengal']
data_india_Bengal = data_india_Bengal.sort_values(by=['Last_Update'])
data_india_bengal_1mar_1apr = data_india_Bengal.head(31)
data_india_bengal_1apr_1may = data_india_Bengal.iloc[31:61,:]
fig,axes=plt.subplots(figsize=(12,6),nrows=1,ncols=2)

axes[0].plot(data_india_bengal_1mar_1apr['Last_Update'],data_india_bengal_1mar_1apr['Confirmed'],color='b')
axes[0].set_xlabel('date')
axes[0].set_ylabel('no of cases')
axes[0].set_title('1 Mar - 1 April')

axes[1].plot(data_india_bengal_1apr_1may['Last_Update'],data_india_bengal_1apr_1may['Confirmed'],color='g')
axes[1].set_xlabel('date')
axes[1].set_ylabel('no of cases')
axes[1].set_title('1 April - 1 May')

plt.tight_layout()

# %%
import seaborn as sns
#april Month :
data_india_april = data_india.loc[data_india['Last_Update']=='2021-04-01 04:27:05']
data_india_april.head(20)
data_india_april.reset_index(inplace = True)
Maxi2=data_india_april.sort_values(by=['Confirmed'],ascending=False)
Maxi2

fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=Maxi2.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="April Month Top 20 States Infected")
plt.show()

# %%
import seaborn as sns
#May Month :
data_india_May = data_india.loc[data_india['Last_Update']=='2021-05-01 04:20:47']
data_india_May.head(20)
data_india_May.reset_index(inplace = True)
Maxi3=data_india_May.sort_values(by=['Confirmed'],ascending=False)
Maxi3

fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=Maxi3.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="May Month Top 20 States Infected")
plt.show()

# %%
import seaborn as sns
#May Month :
data_india_march_mid = data_india.loc[data_india['Last_Update']=='2021-03-15 05:25:51']
data_india_march_mid.head(20)
data_india_march_mid.reset_index(inplace = True)
Maxi4=data_india_march_mid.sort_values(by=['Confirmed'],ascending=False)
Maxi4

fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=Maxi4.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="March Month Top 20 States Infected")
plt.show()

# %%
import seaborn as sns

data_india_april_mid = data_india.loc[data_india['Last_Update']=='2021-04-15 04:20:54']
data_india_april_mid.head(20)
data_india_april_mid.reset_index(inplace = True)
Maxi5=data_india_april_mid.sort_values(by=['Confirmed'],ascending=False)
Maxi5

fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=Maxi5.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="May April Top 20 States Infected")
plt.show()
